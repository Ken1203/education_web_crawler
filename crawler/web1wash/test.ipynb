# %%
from monitor import monitor
import sys
import traceback
import os
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.chrome.options import Options
import requests
from tqdm import tqdm
import pandas as pd
from datetime import datetime 
from sqlalchemy import create_engine
import sqlalchemy
sql="select * from UCOM_ED "
engine = create_engine('mysql+pymysql://ken:3989889@localhost:3306/test') 
df=pd.read_sql(sql,engine)
price_list=[i.replace('費用：NT$ ', '').replace(',', '') for i in df['price']]
hours_list=[j.replace('時數：', '').replace('小時', '') for j in df['hours']]
today=datetime.today().strftime("%Y%m%d")
data_wash=[]
for k in range(len(price_list)):
    a={}
    a['today']=today
    a['title']=df['title'][k]
    a['audience']=df['audience'][k]
    a['price']=price_list[k]
    a['hours']=hours_list[k]
    a['purpose']=df['purpose'][k]
    a['content']=df['content'][k]
    a['during']=df['during'][k]
    data_wash.append(a)
df_wash = pd.DataFrame(data_wash)
df_wash.to_sql('UCOM_ED_wash', engine, index= False,dtype={'price':sqlalchemy.sql.sqltypes.INTEGER,'hours':sqlalchemy.types.Float})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-6f6c755b3f95> in <module>
#      32     data_wash.append(a)
#      33 df_wash = pd.DataFrame(data_wash)
# ---> 34 df_wash.to_sql('UCOM_ED_wash', engine, index= False,dtype={'price':sqlalchemy.sql.sqltypes.INTEGER,'hours':sqlalchemy.types.Float})
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     644         if self.exists():
#     645             if self.if_exists == "fail":
# --> 646                 raise ValueError(f"Table '{self.name}' already exists.")
#     647             elif self.if_exists == "replace":
#     648                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'UCOM_ED_wash' already exists.

# %%
df_wash
# Out:
#        today                            title  \
# 0   20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程
# 1   20200720          CompTIA Network＋國際網路認證班
# 2   20200720                  CDCP資訊機房管理國際認證班
# 3   20200720      Bootstrap網頁實作PHP Apache商業網站
# 4   20200720                全方位網路系統工程師就業認證養成班
# 5   20200720                   JavaScript程式設計
# 6   20200720               企業IT服務伺服器架設與選擇方案導覽
# 7   20200720           Power BI Desktop數據分析實戰
# 8   20200720                    AI電腦視覺OpenCV
# 9   20200720                資訊安全分析實務-方法、流程與工具
# 10  20200720        Systems Operations on AWS
# 11  20200720            CCNA認證-建置與管理Cisco解決方案
# 12  20200720            Apache Hadoop之管理者訓練課程
# 13  20200720           部署及管理Citrix SD-WAN基礎知識
# 14  20200720     EC-Council安全運營中心(SOC)分析師認證課程
# 15  20200720                PostgreSQL資料庫基礎管理
# 16  20200720                   SSCP資安專業人員認證課程
# 17  20200720           ITIL® 4 Foundation認證課程
# 18  20200720             IIB Council區塊鏈專家認證課程
# 19  20200720            Microsoft Azure開發解決方案
# 20  20200720                        Swift程式語言
# 21  20200720                        MySQL效能調校
# 22  20200720                  開發Java EE 7應用程式
# 23  20200720           Oracle Solaris 11 系統管理
# 24  20200720                       Python程式設計
# 25  20200720                  PMP®國際專案管理師培訓課程
# 26  20200720                Red Hat紅帽RHCE認證課程
# 27  20200720           Salesforce平台應用程序建構認證課程
# 28  20200720    Veritas NetBackup資料保護專業人員認證課程
# 29  20200720          VMware vSphere安裝及設定管理課程
# 30  20200720            CCNA認證-建置與管理Cisco解決方案
# 31  20200720            CCNA認證-建置與管理Cisco解決方案
# 32  20200720            Microsoft Azure開發解決方案
# 33  20200720        Systems Operations on AWS
# 34  20200720          VMware Horizon安裝及設定管理課程
# 35  20200720                    AI電腦視覺OpenCV
# 36  20200720                   JavaScript程式設計
# 37  20200720       Kotlin程式設計-Android應用程式開發實務
# 38  20200720                        MySQL效能調校
# 39  20200720           Power BI Desktop數據分析實戰
# 40  20200720     EC-Council安全運營中心(SOC)分析師認證課程
# 41  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程
# 42  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程
# 43  20200720              Dreamweaver專業網頁編輯應用
#
#                                              audience  price hours  \
# 0    適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...  50000    40
# 1            適合對象  跨領域學習工作者 對網路安全技術有興趣者 初階系統/網路工程師     45000    40
# 2    適合對象  資訊機房(Data Center)管理、維護者 資訊機房(Data Cente...  60000    14
# 3    適合對象 有Dreamweaver與Bootstrap使用經驗，希望學會與PHP/MySQ...  12000    24
# 4    適合對象  電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證...  89000   560
# 5    適合對象  想要撰寫或設計網頁的設計師 想要了解用戶端開發技術的程式設計師 想要撰寫網站應...  22000    28
# 6    適合對象  對IT產業有興趣、想從事伺服器管理相關工作者  想學習認識企業建構伺服器有哪些...   6000     7
# 7    適合對象  想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者 ...  20000    21
# 8                    適合對象 已有C++程式設計基礎、Python程式設計基礎者    24000    35
# 9    適合對象  想要學習資安實用操作技巧的IT人員 對系統的資安有興趣管理，希望能加強實作技巧...  28000    35
# 10   適合對象  系統管理人員 軟體開發人員(主要以AWS開發DevOps，搭配營運目的為主；非...  34020    21
# 11   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...  66000    70
# 12              適合對象 1.系統管理人員 2.IT經理 3.RDBMS資料庫管理人員    64000    28
# 13   適合對象 專為使用Citrix SD-WAN的IT專業人員所設計，幾乎沒有以前的SD-WA...  45000    24
# 14   適合對象  SOC分析師(第一級和第二級) 網路和安全管理員 網路和安全工程師 網路防禦分...  39000    24
# 15   適合對象  想要了解PostgreSQL基本管理功能的資料庫管理人員 想要了解Postgr...  38000    18
# 16   適合對象  對資訊安全工作有興趣者 欲取得SSCP®認證資格者 欲充實本身資安技術能力的I...  40000    40
# 17   適合對象 1.中高階營運相關主管 2.資訊長或企業資訊部門的主管 3.即將晉升管理工作之I...  34000    28
# 18   適合對象  商業技術主管 政府技術幕僚 全端工程師(Full Stack Develope...  56000    40
# 19             適合對象 想要建構雲端解決方法(如應用程式與服務等)的Azure開發人員    30000    35
# 20   適合對象  具備程式開發與物件導向設計經驗的程式設計師 想要熟悉Swift程式語言的程式設...  24000    28
# 21   適合對象  維護MySQL伺服器的資料庫管理人員 設計或使用MySQL資料庫的資料庫開發人...  57300    24
# 22   適合對象  希望開發遵循Java EE標準之完整企業應用程式及EJB元件的Java技術程式...  71600    30
# 23                               適合對象  系統管理者 維護工程師     71600    30
# 24                        適合對象 想了解Python程式語言的程式開發人員    18000    28
# 25   適合對象  欲參與考試，取得PMP®證照者 欲找到有效且系統化方法來執行專案之專案經理 欲...  32000    42
# 26   適合對象 1.Linux入門者、具備網路基本架構概念者 2.想要學習一般Linux使用操作...  68000    91
# 27                 適合對象  系統管理員 系統整合人員 獨立軟體供應商(ISV)     66000    35
# 28   適合對象  在其環境中負責Veritas NetBackup安裝、運作或整合的系統或網路管...  75000    40
# 29                               適合對象  系統管理員 系統工程師     69900    35
# 30   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...  66000    70
# 31   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...  66000    70
# 32             適合對象 想要建構雲端解決方法(如應用程式與服務等)的Azure開發人員    30000    35
# 33   適合對象  系統管理人員 軟體開發人員(主要以AWS開發DevOps，搭配營運目的為主；非...  34020    21
# 34          適合對象 終端客戶公司的IT部門技術人員，以及負責交付遠端或虛擬桌面服務的人員    69900    35
# 35                   適合對象 已有C++程式設計基礎、Python程式設計基礎者    24000    35
# 36   適合對象  想要撰寫或設計網頁的設計師 想要了解用戶端開發技術的程式設計師 想要撰寫網站應...  22000    28
# 37   適合對象 1.想學習Kotlin程式語言的應用程式開發人員 2.已經熟悉Java程式設計語...  24000    35
# 38   適合對象  維護MySQL伺服器的資料庫管理人員 設計或使用MySQL資料庫的資料庫開發人...  57300    24
# 39   適合對象  想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者 ...  20000    21
# 40   適合對象  SOC分析師(第一級和第二級) 網路和安全管理員 網路和安全工程師 網路防禦分...  39000    24
# 41   適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...  50000    40
# 42   適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...  50000    40
# 43                             適合對象 欲學習專業網站建置與編輯應用者     8400    24
#
#                                               purpose  \
# 0   此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 1   資訊與通信科技（Information and Communication Technolo...
# 2   現階段大多數企業都建置IT系統，依靠IT提供關鍵服務，因此資訊機房(Data Center)...
# 3   Dreamweaver CC 2015之後的版本，已將Bootstrap整合為內建功能，因此...
# 4   根據 104 人力銀行「2020 薪酬趨白皮書調查」指出，產業加薪幅度三強分別為： 軟體及網...
# 5   由於網站應用程式的盛行，已經讓JavaScript變成世界最受歡迎的程式語言之一，也是最廣泛...
# 6   IT的e化環境，與企業架設伺服器息息相關，這也是企業系統管理員主要的工作內容之一。所以就了解...
# 7   數據分析已成為目前企業決勝的關鍵，唯有對手上的資料數據了解的越多，我們也才能做的更多及更好。...
# 8   OpenCV是一個行之有年的影像處理函式庫，除了用在傳統的影像應用程式之外，更被用於各式的深...
# 9   建立一套標準化的流程，將資訊安全的理論應用於各種日常維運的系統環境中，並順利通過資安弱點掃描...
# 10  當雲端部署蔚為時尚時，有效率的管理相形之下就顯得非常重要。在AWS平台上能以自動化的方式部署...
# 11  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 12  本課程將教您關於管理、操作、維護Hadoop叢集所需必要步驟的廣泛介紹。從安裝、組態到負載平...
# 13  學習各種可用的SD-WAN實作和部署模式，以及如何選擇適合您組織的模式。瀏覽SD-WAN的深...
# 14  隨著資訊安全領域的不斷擴展，SOC團隊需要提供高質量的IT安全服務，以主動檢測潛在的網路威脅...
# 15  本課程為PostgreSQL資料庫管理的入門課程，可以學習到管理PostgreSQL資料庫所...
# 16  *此課程為「行政院國家資通安全會報」認可之資通安全專業證照 對於有志從事資訊安全工作者，該如...
# 17  本課程將輔導您具備通過ITIL® 4 Foundation認證考試的能力，協助您了解ITIL...
# 18  網路傳遞資訊，區塊鏈傳遞價值。區塊鏈是去中心化(decentralization)策略的基石...
# 19  這門課程主要是讓您了解如何開發Azure的基礎架構，牽涉到開發過程的全部階段，包括從解決方法...
# 20  iPhone與iPad是目前Apple最火紅的行動上網裝置，為了簡化Objective-C與...
# 21  您需要管理MySQL應用中不斷增加的資料嗎？您想監控與診斷MySQL的疑難雜症並調校其最佳效...
# 22  本課程將教導建立Java EE 7應用程式的相關知識。課程內容涵蓋必要的Java EE元件，...
# 23  本課程介紹 Oracle Solaris 11 作業環境的基本管理，從安裝、升級、軟體套件、...
# 24  Python是一種物件導向、直譯式的電腦程式語言。它的語法簡單，能夠輕鬆完成很多常見的任務，...
# 25  培訓專案經理及企業主管人才，使其具備「專案自起始、規劃、執行、監控至結束」所需的管理知識與標...
# 26  雲端！絶對是當下最為熱門的話題之一，也是未來網路服務的主軸，這方向肯定是不會改變的，因Red...
# 27  通過此次培訓，您將具備一定的專業性，掌握Salesforce的一整套點擊式設定，不需編寫程式...
# 28  本課程提供Veritas NetBackup 8.1版軟體功能的教學。課程設計旨在提供您使用...
# 29  This five-day course features intensive hands-...
# 30  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 31  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 32  這門課程主要是讓您了解如何開發Azure的基礎架構，牽涉到開發過程的全部階段，包括從解決方法...
# 33  當雲端部署蔚為時尚時，有效率的管理相形之下就顯得非常重要。在AWS平台上能以自動化的方式部署...
# 34  This five-day, hands-on course gives you the s...
# 35  OpenCV是一個行之有年的影像處理函式庫，除了用在傳統的影像應用程式之外，更被用於各式的深...
# 36  由於網站應用程式的盛行，已經讓JavaScript變成世界最受歡迎的程式語言之一，也是最廣泛...
# 37  針對想要使用Kotlin開發Android應用程式設計的課程，適合初學或具備Java、And...
# 38  您需要管理MySQL應用中不斷增加的資料嗎？您想監控與診斷MySQL的疑難雜症並調校其最佳效...
# 39  數據分析已成為目前企業決勝的關鍵，唯有對手上的資料數據了解的越多，我們也才能做的更多及更好。...
# 40  隨著資訊安全領域的不斷擴展，SOC團隊需要提供高質量的IT安全服務，以主動檢測潛在的網路威脅...
# 41  此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 42  此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 43  本課程將學習如何從網頁的基礎內容編輯開始，進行HTML檔案格式的編排與設計，了解網頁格式的特...
#
#                                               content  \
# 0   1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...
# 1    Explain the OSI and TCP/IP Models (解釋OSI和TCP/...
# 2   Importance and Causes for Downtime Standards a...
# 3   1.Bootstrap頁面準備與相關擴充元件應用 1-1.建構Bootstrap頁面 1-2...
# 4   網路基礎  網路基礎架構與網路服務  Windows系統管理建置  Windows Serv...
# 5    JavaScript簡介 JavaScript變數宣告方式、變數範圍、程式語法與基本型別 ...
# 6    企業常見IT伺服器平台介紹 企業常見IT伺服器應用介紹 File伺服器介紹 Proxy/N...
# 7    Power BI產品組合介紹 Power BI Desktop的下載與安裝 Power B...
# 8   1.編譯安裝OpenCV 2.Python與OpenCV的連結 3.圖片處理與標記 4.影像...
# 9    評估系統的資訊安全 評估流程與相關工具 列舉與入侵系統的參考步驟 駭客的矛盾對決 探索與測...
# 10   System Operations on AWS概論 在雲端的網路與運算 在雲端的資料倉儲...
# 11  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...
# 12  1.Introduction 2.Cloudera Enterprise Data Hub ...
# 13   Citrix SD-WAN簡介和概述 •      CitrixSD-WAN功能 •   ...
# 14   安全運營和管理(Security Operations and Management) 了...
# 15   PostgreSQL系統架構(PostgreSQL System Architecture...
# 16  第一章 Introducing Security and Aligning Asset Ma...
# 17  1.ITIL®4基礎 1-1 ITIL®4 概述(Overview of ITIL®4) 1...
# 18   掌握區塊鏈技術的理論和技術基礎 了解去中心化(decentralization)的概念，其...
# 19   建立、設定、監控以及延展Azure App Service Web Apps 實作Azur...
# 20   Xcode開發工具介紹 Swift簡介 Swift基本語法結構 Swift運算子與流程控制...
# 21   課程介紹 效能調校概念說明 效能調校工具介紹 Performance Schema說明 伺...
# 22   Java EE概論、Java EE模組與元件開發步驟 使用Netbeans開發工具 使用J...
# 23   安裝Oracle Solaris 11 使用IPS 升級 Oracle Solaris 1...
# 24   Python語言及開發環境介紹 資料型別 集合 結構控制 函數 模組(Module) 物件...
# 25  PMBOK® Guide-Sixth Edition+Agile Practice Guid...
# 26   RH124： Red Hat紅帽系統管理 I (35小時) RH134： Red Hat紅...
# 27   構建資料模型 1-1    核心CRM物件的功能 1-2    聲明式客製的界限 1-3 ...
# 28   介紹Veritas NetBackup 設定NetBackup儲存單元 建立備立政策及排程...
# 29   Course Introduction Introduction to vSphere a...
# 30  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...
# 31  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...
# 32   建立、設定、監控以及延展Azure App Service Web Apps 實作Azur...
# 33   System Operations on AWS概論 在雲端的網路與運算 在雲端的資料倉儲...
# 34   Course Introduction Introduction to VMware Ho...
# 35  1.編譯安裝OpenCV 2.Python與OpenCV的連結 3.圖片處理與標記 4.影像...
# 36   JavaScript簡介 JavaScript變數宣告方式、變數範圍、程式語法與基本型別 ...
# 37    Kotlin程式設計語言基礎 設計函式 類別與物件 物件導向程式設計 列舉型態、常數與資...
# 38   課程介紹 效能調校概念說明 效能調校工具介紹 Performance Schema說明 伺...
# 39   Power BI產品組合介紹 Power BI Desktop的下載與安裝 Power B...
# 40   安全運營和管理(Security Operations and Management) 了...
# 41  1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...
# 42  1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...
# 43  1.網站定義與基本操作  1-1網頁檔案基本規則 1-2 定義網站 1-3 檔案基本操作 1...
#
#                                                during
# 0   ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 1   ['2020/07/27 ~ 2020/07/31 每週一二三四五', '2020/08/1...
# 2   ['2020/07/27 ~ 2020/07/28 每週一二', '2020/08/20 ~...
# 3   ['2020/09/14 ~ 2020/10/07 每週一三', '2020/10/26 ~...
# 4   ['2020/07/31 ~ 2021/01/19 每週一二四五', '2020/11/09...
# 5   ['2020/08/15 ~ 2020/08/23 每週六日', '2020/10/19 ~...
# 6                     ['2020/10/30 ~ 2020/10/30 每週五']
# 7   ['2020/08/03 ~ 2020/08/05 每週一二三', '2020/10/31 ...
# 8                 ['2020/11/23 ~ 2020/11/27 每週一二三四五']
# 9   ['2020/07/25 ~ 2020/08/09 每週六日', '2020/10/12 ~...
# 10  ['2020/09/28 ~ 2020/09/30 每週一二三', '2020/11/30 ...
# 11  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 12                 ['2020/09/22 ~ 2020/09/25 每週二三四五']
# 13                                                 []
# 14  ['2020/08/12 ~ 2020/08/14 每週三四五', '2020/10/05 ...
# 15                  ['2020/09/28 ~ 2020/09/30 每週一二三']
# 16  ['2020/08/31 ~ 2020/09/04 每週一二三四五', '2020/10/2...
# 17  ['2020/08/17 ~ 2020/08/20 每週一二三四', '2020/09/05...
# 18  ['2020/08/24 ~ 2020/08/28 每週一二三四五', '2020/11/3...
# 19                ['2020/09/21 ~ 2020/09/25 每週一二三四五']
# 20                 ['2020/11/24 ~ 2020/11/27 每週二三四五']
# 21                  ['2020/08/24 ~ 2020/08/26 每週一二三']
# 22                ['2020/11/09 ~ 2020/11/13 每週一二三四五']
# 23                ['2020/10/19 ~ 2020/10/23 每週一二三四五']
# 24  ['2020/08/10 ~ 2020/08/13 每週一二三四', '2020/09/05...
# 25  ['2020/08/05 ~ 2020/08/14 每週三四五', '2020/08/15 ...
# 26  ['2020/08/20 ~ 2020/11/19 每週二四', '2020/09/12 ~...
# 27                ['2020/10/26 ~ 2020/10/30 每週一二三四五']
# 28                ['2020/09/14 ~ 2020/09/18 每週一二三四五']
# 29  ['2020/08/03 ~ 2020/08/07 每週一二三四五', '2020/08/2...
# 30  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 31  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 32                ['2020/09/21 ~ 2020/09/25 每週一二三四五']
# 33  ['2020/09/28 ~ 2020/09/30 每週一二三', '2020/11/30 ...
# 34                ['2020/09/14 ~ 2020/09/18 每週一二三四五']
# 35                ['2020/11/23 ~ 2020/11/27 每週一二三四五']
# 36  ['2020/08/15 ~ 2020/08/23 每週六日', '2020/10/19 ~...
# 37  ['2020/08/31 ~ 2020/09/04 每週一二三四五', '2020/09/0...
# 38                  ['2020/08/24 ~ 2020/08/26 每週一二三']
# 39  ['2020/08/03 ~ 2020/08/05 每週一二三', '2020/10/31 ...
# 40  ['2020/08/12 ~ 2020/08/14 每週三四五', '2020/10/05 ...
# 41  ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 42  ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 43  ['2020/09/07 ~ 2020/09/10 每週一二三四五', '2020/10/1...

# %%
df
# Out:
#     id     today                            title          price  \
# 0    0  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程  費用：NT$ 50,000
# 1    1  20200720          CompTIA Network＋國際網路認證班  費用：NT$ 45,000
# 2    2  20200720                  CDCP資訊機房管理國際認證班  費用：NT$ 60,000
# 3    3  20200720      Bootstrap網頁實作PHP Apache商業網站  費用：NT$ 12,000
# 4    4  20200720                全方位網路系統工程師就業認證養成班  費用：NT$ 89,000
# 5    5  20200720                   JavaScript程式設計  費用：NT$ 22,000
# 6    6  20200720               企業IT服務伺服器架設與選擇方案導覽   費用：NT$ 6,000
# 7    7  20200720           Power BI Desktop數據分析實戰  費用：NT$ 20,000
# 8    8  20200720                    AI電腦視覺OpenCV   費用：NT$ 24,000
# 9    9  20200720                資訊安全分析實務-方法、流程與工具  費用：NT$ 28,000
# 10  10  20200720        Systems Operations on AWS  費用：NT$ 34,020
# 11  11  20200720            CCNA認證-建置與管理Cisco解決方案  費用：NT$ 66,000
# 12  12  20200720            Apache Hadoop之管理者訓練課程  費用：NT$ 64,000
# 13  13  20200720           部署及管理Citrix SD-WAN基礎知識  費用：NT$ 45,000
# 14  14  20200720     EC-Council安全運營中心(SOC)分析師認證課程  費用：NT$ 39,000
# 15  15  20200720                PostgreSQL資料庫基礎管理  費用：NT$ 38,000
# 16  16  20200720                   SSCP資安專業人員認證課程  費用：NT$ 40,000
# 17  17  20200720           ITIL® 4 Foundation認證課程  費用：NT$ 34,000
# 18  18  20200720             IIB Council區塊鏈專家認證課程  費用：NT$ 56,000
# 19  19  20200720            Microsoft Azure開發解決方案  費用：NT$ 30,000
# 20  20  20200720                        Swift程式語言  費用：NT$ 24,000
# 21  21  20200720                        MySQL效能調校  費用：NT$ 57,300
# 22  22  20200720                  開發Java EE 7應用程式  費用：NT$ 71,600
# 23  23  20200720           Oracle Solaris 11 系統管理  費用：NT$ 71,600
# 24  24  20200720                       Python程式設計  費用：NT$ 18,000
# 25  25  20200720                  PMP®國際專案管理師培訓課程  費用：NT$ 32,000
# 26  26  20200720                Red Hat紅帽RHCE認證課程  費用：NT$ 68,000
# 27  27  20200720           Salesforce平台應用程序建構認證課程  費用：NT$ 66,000
# 28  28  20200720    Veritas NetBackup資料保護專業人員認證課程  費用：NT$ 75,000
# 29  29  20200720          VMware vSphere安裝及設定管理課程  費用：NT$ 69,900
# 30  30  20200720            CCNA認證-建置與管理Cisco解決方案  費用：NT$ 66,000
# 31  31  20200720            CCNA認證-建置與管理Cisco解決方案  費用：NT$ 66,000
# 32  32  20200720            Microsoft Azure開發解決方案  費用：NT$ 30,000
# 33  33  20200720        Systems Operations on AWS  費用：NT$ 34,020
# 34  34  20200720          VMware Horizon安裝及設定管理課程  費用：NT$ 69,900
# 35  35  20200720                    AI電腦視覺OpenCV   費用：NT$ 24,000
# 36  36  20200720                   JavaScript程式設計  費用：NT$ 22,000
# 37  37  20200720       Kotlin程式設計-Android應用程式開發實務  費用：NT$ 24,000
# 38  38  20200720                        MySQL效能調校  費用：NT$ 57,300
# 39  39  20200720           Power BI Desktop數據分析實戰  費用：NT$ 20,000
# 40  40  20200720     EC-Council安全運營中心(SOC)分析師認證課程  費用：NT$ 39,000
# 41  41  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程  費用：NT$ 50,000
# 42  42  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程  費用：NT$ 50,000
# 43  43  20200720              Dreamweaver專業網頁編輯應用   費用：NT$ 8,400
#
#                                                during  \
# 0   ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 1   ['2020/07/27 ~ 2020/07/31 每週一二三四五', '2020/08/1...
# 2   ['2020/07/27 ~ 2020/07/28 每週一二', '2020/08/20 ~...
# 3   ['2020/09/14 ~ 2020/10/07 每週一三', '2020/10/26 ~...
# 4   ['2020/07/31 ~ 2021/01/19 每週一二四五', '2020/11/09...
# 5   ['2020/08/15 ~ 2020/08/23 每週六日', '2020/10/19 ~...
# 6                     ['2020/10/30 ~ 2020/10/30 每週五']
# 7   ['2020/08/03 ~ 2020/08/05 每週一二三', '2020/10/31 ...
# 8                 ['2020/11/23 ~ 2020/11/27 每週一二三四五']
# 9   ['2020/07/25 ~ 2020/08/09 每週六日', '2020/10/12 ~...
# 10  ['2020/09/28 ~ 2020/09/30 每週一二三', '2020/11/30 ...
# 11  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 12                 ['2020/09/22 ~ 2020/09/25 每週二三四五']
# 13                                                 []
# 14  ['2020/08/12 ~ 2020/08/14 每週三四五', '2020/10/05 ...
# 15                  ['2020/09/28 ~ 2020/09/30 每週一二三']
# 16  ['2020/08/31 ~ 2020/09/04 每週一二三四五', '2020/10/2...
# 17  ['2020/08/17 ~ 2020/08/20 每週一二三四', '2020/09/05...
# 18  ['2020/08/24 ~ 2020/08/28 每週一二三四五', '2020/11/3...
# 19                ['2020/09/21 ~ 2020/09/25 每週一二三四五']
# 20                 ['2020/11/24 ~ 2020/11/27 每週二三四五']
# 21                  ['2020/08/24 ~ 2020/08/26 每週一二三']
# 22                ['2020/11/09 ~ 2020/11/13 每週一二三四五']
# 23                ['2020/10/19 ~ 2020/10/23 每週一二三四五']
# 24  ['2020/08/10 ~ 2020/08/13 每週一二三四', '2020/09/05...
# 25  ['2020/08/05 ~ 2020/08/14 每週三四五', '2020/08/15 ...
# 26  ['2020/08/20 ~ 2020/11/19 每週二四', '2020/09/12 ~...
# 27                ['2020/10/26 ~ 2020/10/30 每週一二三四五']
# 28                ['2020/09/14 ~ 2020/09/18 每週一二三四五']
# 29  ['2020/08/03 ~ 2020/08/07 每週一二三四五', '2020/08/2...
# 30  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 31  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 32                ['2020/09/21 ~ 2020/09/25 每週一二三四五']
# 33  ['2020/09/28 ~ 2020/09/30 每週一二三', '2020/11/30 ...
# 34                ['2020/09/14 ~ 2020/09/18 每週一二三四五']
# 35                ['2020/11/23 ~ 2020/11/27 每週一二三四五']
# 36  ['2020/08/15 ~ 2020/08/23 每週六日', '2020/10/19 ~...
# 37  ['2020/08/31 ~ 2020/09/04 每週一二三四五', '2020/09/0...
# 38                  ['2020/08/24 ~ 2020/08/26 每週一二三']
# 39  ['2020/08/03 ~ 2020/08/05 每週一二三', '2020/10/31 ...
# 40  ['2020/08/12 ~ 2020/08/14 每週三四五', '2020/10/05 ...
# 41  ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 42  ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 43  ['2020/09/07 ~ 2020/09/10 每週一二三四五', '2020/10/1...
#
#                                              audience  \
# 0    適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...
# 1            適合對象  跨領域學習工作者 對網路安全技術有興趣者 初階系統/網路工程師
# 2    適合對象  資訊機房(Data Center)管理、維護者 資訊機房(Data Cente...
# 3    適合對象 有Dreamweaver與Bootstrap使用經驗，希望學會與PHP/MySQ...
# 4    適合對象  電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證...
# 5    適合對象  想要撰寫或設計網頁的設計師 想要了解用戶端開發技術的程式設計師 想要撰寫網站應...
# 6    適合對象  對IT產業有興趣、想從事伺服器管理相關工作者  想學習認識企業建構伺服器有哪些...
# 7    適合對象  想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者 ...
# 8                    適合對象 已有C++程式設計基礎、Python程式設計基礎者
# 9    適合對象  想要學習資安實用操作技巧的IT人員 對系統的資安有興趣管理，希望能加強實作技巧...
# 10   適合對象  系統管理人員 軟體開發人員(主要以AWS開發DevOps，搭配營運目的為主；非...
# 11   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...
# 12              適合對象 1.系統管理人員 2.IT經理 3.RDBMS資料庫管理人員
# 13   適合對象 專為使用Citrix SD-WAN的IT專業人員所設計，幾乎沒有以前的SD-WA...
# 14   適合對象  SOC分析師(第一級和第二級) 網路和安全管理員 網路和安全工程師 網路防禦分...
# 15   適合對象  想要了解PostgreSQL基本管理功能的資料庫管理人員 想要了解Postgr...
# 16   適合對象  對資訊安全工作有興趣者 欲取得SSCP®認證資格者 欲充實本身資安技術能力的I...
# 17   適合對象 1.中高階營運相關主管 2.資訊長或企業資訊部門的主管 3.即將晉升管理工作之I...
# 18   適合對象  商業技術主管 政府技術幕僚 全端工程師(Full Stack Develope...
# 19             適合對象 想要建構雲端解決方法(如應用程式與服務等)的Azure開發人員
# 20   適合對象  具備程式開發與物件導向設計經驗的程式設計師 想要熟悉Swift程式語言的程式設...
# 21   適合對象  維護MySQL伺服器的資料庫管理人員 設計或使用MySQL資料庫的資料庫開發人...
# 22   適合對象  希望開發遵循Java EE標準之完整企業應用程式及EJB元件的Java技術程式...
# 23                               適合對象  系統管理者 維護工程師
# 24                        適合對象 想了解Python程式語言的程式開發人員
# 25   適合對象  欲參與考試，取得PMP®證照者 欲找到有效且系統化方法來執行專案之專案經理 欲...
# 26   適合對象 1.Linux入門者、具備網路基本架構概念者 2.想要學習一般Linux使用操作...
# 27                 適合對象  系統管理員 系統整合人員 獨立軟體供應商(ISV)
# 28   適合對象  在其環境中負責Veritas NetBackup安裝、運作或整合的系統或網路管...
# 29                               適合對象  系統管理員 系統工程師
# 30   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...
# 31   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...
# 32             適合對象 想要建構雲端解決方法(如應用程式與服務等)的Azure開發人員
# 33   適合對象  系統管理人員 軟體開發人員(主要以AWS開發DevOps，搭配營運目的為主；非...
# 34          適合對象 終端客戶公司的IT部門技術人員，以及負責交付遠端或虛擬桌面服務的人員
# 35                   適合對象 已有C++程式設計基礎、Python程式設計基礎者
# 36   適合對象  想要撰寫或設計網頁的設計師 想要了解用戶端開發技術的程式設計師 想要撰寫網站應...
# 37   適合對象 1.想學習Kotlin程式語言的應用程式開發人員 2.已經熟悉Java程式設計語...
# 38   適合對象  維護MySQL伺服器的資料庫管理人員 設計或使用MySQL資料庫的資料庫開發人...
# 39   適合對象  想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者 ...
# 40   適合對象  SOC分析師(第一級和第二級) 網路和安全管理員 網路和安全工程師 網路防禦分...
# 41   適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...
# 42   適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...
# 43                             適合對象 欲學習專業網站建置與編輯應用者
#
#                                               content     hours  \
# 0   1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...   時數：40小時
# 1    Explain the OSI and TCP/IP Models (解釋OSI和TCP/...   時數：40小時
# 2   Importance and Causes for Downtime Standards a...   時數：14小時
# 3   1.Bootstrap頁面準備與相關擴充元件應用 1-1.建構Bootstrap頁面 1-2...   時數：24小時
# 4   網路基礎  網路基礎架構與網路服務  Windows系統管理建置  Windows Serv...  時數：560小時
# 5    JavaScript簡介 JavaScript變數宣告方式、變數範圍、程式語法與基本型別 ...   時數：28小時
# 6    企業常見IT伺服器平台介紹 企業常見IT伺服器應用介紹 File伺服器介紹 Proxy/N...    時數：7小時
# 7    Power BI產品組合介紹 Power BI Desktop的下載與安裝 Power B...   時數：21小時
# 8   1.編譯安裝OpenCV 2.Python與OpenCV的連結 3.圖片處理與標記 4.影像...   時數：35小時
# 9    評估系統的資訊安全 評估流程與相關工具 列舉與入侵系統的參考步驟 駭客的矛盾對決 探索與測...   時數：35小時
# 10   System Operations on AWS概論 在雲端的網路與運算 在雲端的資料倉儲...   時數：21小時
# 11  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...   時數：70小時
# 12  1.Introduction 2.Cloudera Enterprise Data Hub ...   時數：28小時
# 13   Citrix SD-WAN簡介和概述 •      CitrixSD-WAN功能 •   ...   時數：24小時
# 14   安全運營和管理(Security Operations and Management) 了...   時數：24小時
# 15   PostgreSQL系統架構(PostgreSQL System Architecture...   時數：18小時
# 16  第一章 Introducing Security and Aligning Asset Ma...   時數：40小時
# 17  1.ITIL®4基礎 1-1 ITIL®4 概述(Overview of ITIL®4) 1...   時數：28小時
# 18   掌握區塊鏈技術的理論和技術基礎 了解去中心化(decentralization)的概念，其...   時數：40小時
# 19   建立、設定、監控以及延展Azure App Service Web Apps 實作Azur...   時數：35小時
# 20   Xcode開發工具介紹 Swift簡介 Swift基本語法結構 Swift運算子與流程控制...   時數：28小時
# 21   課程介紹 效能調校概念說明 效能調校工具介紹 Performance Schema說明 伺...   時數：24小時
# 22   Java EE概論、Java EE模組與元件開發步驟 使用Netbeans開發工具 使用J...   時數：30小時
# 23   安裝Oracle Solaris 11 使用IPS 升級 Oracle Solaris 1...   時數：30小時
# 24   Python語言及開發環境介紹 資料型別 集合 結構控制 函數 模組(Module) 物件...   時數：28小時
# 25  PMBOK® Guide-Sixth Edition+Agile Practice Guid...   時數：42小時
# 26   RH124： Red Hat紅帽系統管理 I (35小時) RH134： Red Hat紅...   時數：91小時
# 27   構建資料模型 1-1    核心CRM物件的功能 1-2    聲明式客製的界限 1-3 ...   時數：35小時
# 28   介紹Veritas NetBackup 設定NetBackup儲存單元 建立備立政策及排程...   時數：40小時
# 29   Course Introduction Introduction to vSphere a...   時數：35小時
# 30  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...   時數：70小時
# 31  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...   時數：70小時
# 32   建立、設定、監控以及延展Azure App Service Web Apps 實作Azur...   時數：35小時
# 33   System Operations on AWS概論 在雲端的網路與運算 在雲端的資料倉儲...   時數：21小時
# 34   Course Introduction Introduction to VMware Ho...   時數：35小時
# 35  1.編譯安裝OpenCV 2.Python與OpenCV的連結 3.圖片處理與標記 4.影像...   時數：35小時
# 36   JavaScript簡介 JavaScript變數宣告方式、變數範圍、程式語法與基本型別 ...   時數：28小時
# 37    Kotlin程式設計語言基礎 設計函式 類別與物件 物件導向程式設計 列舉型態、常數與資...   時數：35小時
# 38   課程介紹 效能調校概念說明 效能調校工具介紹 Performance Schema說明 伺...   時數：24小時
# 39   Power BI產品組合介紹 Power BI Desktop的下載與安裝 Power B...   時數：21小時
# 40   安全運營和管理(Security Operations and Management) 了...   時數：24小時
# 41  1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...   時數：40小時
# 42  1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...   時數：40小時
# 43  1.網站定義與基本操作  1-1網頁檔案基本規則 1-2 定義網站 1-3 檔案基本操作 1...   時數：24小時
#
#                                               purpose
# 0   此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 1   資訊與通信科技（Information and Communication Technolo...
# 2   現階段大多數企業都建置IT系統，依靠IT提供關鍵服務，因此資訊機房(Data Center)...
# 3   Dreamweaver CC 2015之後的版本，已將Bootstrap整合為內建功能，因此...
# 4   根據 104 人力銀行「2020 薪酬趨白皮書調查」指出，產業加薪幅度三強分別為： 軟體及網...
# 5   由於網站應用程式的盛行，已經讓JavaScript變成世界最受歡迎的程式語言之一，也是最廣泛...
# 6   IT的e化環境，與企業架設伺服器息息相關，這也是企業系統管理員主要的工作內容之一。所以就了解...
# 7   數據分析已成為目前企業決勝的關鍵，唯有對手上的資料數據了解的越多，我們也才能做的更多及更好。...
# 8   OpenCV是一個行之有年的影像處理函式庫，除了用在傳統的影像應用程式之外，更被用於各式的深...
# 9   建立一套標準化的流程，將資訊安全的理論應用於各種日常維運的系統環境中，並順利通過資安弱點掃描...
# 10  當雲端部署蔚為時尚時，有效率的管理相形之下就顯得非常重要。在AWS平台上能以自動化的方式部署...
# 11  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 12  本課程將教您關於管理、操作、維護Hadoop叢集所需必要步驟的廣泛介紹。從安裝、組態到負載平...
# 13  學習各種可用的SD-WAN實作和部署模式，以及如何選擇適合您組織的模式。瀏覽SD-WAN的深...
# 14  隨著資訊安全領域的不斷擴展，SOC團隊需要提供高質量的IT安全服務，以主動檢測潛在的網路威脅...
# 15  本課程為PostgreSQL資料庫管理的入門課程，可以學習到管理PostgreSQL資料庫所...
# 16  *此課程為「行政院國家資通安全會報」認可之資通安全專業證照 對於有志從事資訊安全工作者，該如...
# 17  本課程將輔導您具備通過ITIL® 4 Foundation認證考試的能力，協助您了解ITIL...
# 18  網路傳遞資訊，區塊鏈傳遞價值。區塊鏈是去中心化(decentralization)策略的基石...
# 19  這門課程主要是讓您了解如何開發Azure的基礎架構，牽涉到開發過程的全部階段，包括從解決方法...
# 20  iPhone與iPad是目前Apple最火紅的行動上網裝置，為了簡化Objective-C與...
# 21  您需要管理MySQL應用中不斷增加的資料嗎？您想監控與診斷MySQL的疑難雜症並調校其最佳效...
# 22  本課程將教導建立Java EE 7應用程式的相關知識。課程內容涵蓋必要的Java EE元件，...
# 23  本課程介紹 Oracle Solaris 11 作業環境的基本管理，從安裝、升級、軟體套件、...
# 24  Python是一種物件導向、直譯式的電腦程式語言。它的語法簡單，能夠輕鬆完成很多常見的任務，...
# 25  培訓專案經理及企業主管人才，使其具備「專案自起始、規劃、執行、監控至結束」所需的管理知識與標...
# 26  雲端！絶對是當下最為熱門的話題之一，也是未來網路服務的主軸，這方向肯定是不會改變的，因Red...
# 27  通過此次培訓，您將具備一定的專業性，掌握Salesforce的一整套點擊式設定，不需編寫程式...
# 28  本課程提供Veritas NetBackup 8.1版軟體功能的教學。課程設計旨在提供您使用...
# 29  This five-day course features intensive hands-...
# 30  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 31  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 32  這門課程主要是讓您了解如何開發Azure的基礎架構，牽涉到開發過程的全部階段，包括從解決方法...
# 33  當雲端部署蔚為時尚時，有效率的管理相形之下就顯得非常重要。在AWS平台上能以自動化的方式部署...
# 34  This five-day, hands-on course gives you the s...
# 35  OpenCV是一個行之有年的影像處理函式庫，除了用在傳統的影像應用程式之外，更被用於各式的深...
# 36  由於網站應用程式的盛行，已經讓JavaScript變成世界最受歡迎的程式語言之一，也是最廣泛...
# 37  針對想要使用Kotlin開發Android應用程式設計的課程，適合初學或具備Java、And...
# 38  您需要管理MySQL應用中不斷增加的資料嗎？您想監控與診斷MySQL的疑難雜症並調校其最佳效...
# 39  數據分析已成為目前企業決勝的關鍵，唯有對手上的資料數據了解的越多，我們也才能做的更多及更好。...
# 40  隨著資訊安全領域的不斷擴展，SOC團隊需要提供高質量的IT安全服務，以主動檢測潛在的網路威脅...
# 41  此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 42  此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 43  本課程將學習如何從網頁的基礎內容編輯開始，進行HTML檔案格式的編排與設計，了解網頁格式的特...

# %%
from monitor import monitor
import sys
import traceback
import os
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.chrome.options import Options
import requests
from tqdm import tqdm
import pandas as pd
from datetime import datetime 
from sqlalchemy import create_engine
import sqlalchemy
import pymysql

# %%
def UCOM_ED_wash():
    try:
        sql="select * from UCOM_ED "
#        engine = create_engine('mysql+pymysql://'+loguser+':'+logpw+'@'+logip+':3306/'+logdb)
        engine = create_engine('mysql+pymysql://ken:3989889@localhost:3306/test') 
        df=pd.read_sql(sql,engine)
 #===============報各種可能錯誤==================================================        
    except Exception as e:
#         now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
#         with open(detailerr,'a+') as file:            
#             file.write(now+'執行完第ㄧ步驟的錯誤為: '+str(e))
#             file.write('\n')
        print(e) #報錯誤    
    finally:
        return engine,df

# %%
def data_wash(df):
    try:
        price_list=[]
        for i in df['price']:
            price_list.append(i.replace('費用：NT$ ', '').replace(',', ''))            
#         price_list=[i.replace('費用：NT$ ', '').replace(',', '') for i in df['price']]
        hours_list=[]
        for j in df['hours']:
            hours_list.append(j.replace('時數：', '').replace('小時', ''))
#         hours_list=[j.replace('時數：', '').replace('小時', '') for j in df['hours']]
    except:
#         now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
#         with open(detailerr,'a+') as file:            
#             file.write(now+'執行完第二步驟的錯誤為: '+str(e))
#             file.write('\n')
        print(e) #報錯誤
    finally:
        return price_list,hours_list

# %%
def data_Frame(df,price_list,hours_list):
    try:
        today=datetime.today().strftime("%Y%m%d")
        data_wash=[]
        for k in range(len(price_list)):
            a={}
            a['today']=today
            a['title']=df['title'][k]
            a['audience']=df['audience'][k]
            a['price']=price_list[k]
            a['hours']=hours_list[k]
            a['purpose']=df['purpose'][k]
            a['content']=df['content'][k]
            a['during']=df['during'][k]
            data_wash.append(a)
        df_wash = pd.DataFrame(data_wash)
    except Exception as e:
#         now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
#         with open(detailerr,'a+') as file:            
#             file.write(now+'執行完第三步驟的錯誤為: '+str(e))
#             file.write('\n')
        print(e) #報錯誤
    finally:
        return df_wash

# %%
def indatabase(df_wash,engine):
    try:
        dtype1={
            'today': sqlalchemy.types.Text(),
            'title':sqlalchemy.types.Text(),
            'audience':sqlalchemy.types.Text(),
            'price':sqlalchemy.types.INTEGER(),
            'hours':sqlalchemy.types.Float(precision=1),                       
            'purpose':sqlalchemy.types.Text(),
            'content':sqlalchemy.types.Text(),
            'during':sqlalchemy.types.Text()
        }
        df_wash.to_sql('UCOM_ED_wash',engine, index= False,dtype=dtype1)
        #dtype後面塞想指定column的型態 
#         now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
#         with open(detailerr,'a+') as file:            
#             file.write(now+'執行完第四步驟時: 新增成功')
#             file.write('\n')
        print("新增成功")
    except Exception as e:
#         now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
#         with open(detailerr,'a+') as file:            
#             file.write(now+'執行完第四步驟的錯誤為: '+str(e)+',新增失敗')
#            file.write('\n')
        print(str(e))
        print("新增失敗")
    finally:
#         now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
#         with open(detailerr,'a+') as file:            
#             file.write(now+'第四步驟:寫入結束')
#             file.write('\n')
        print("結束寫入")

# %%
#function1
engine,df = UCOM_ED_wash()
price_list,hours_list = data_wash(df)

df_wash = data_Frame(df,price_list,hours_list)

indatabase(df_wash,engine)
# Out:
#        today                            title  \
# 0   20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程
# 1   20200720          CompTIA Network＋國際網路認證班
# 2   20200720                  CDCP資訊機房管理國際認證班
# 3   20200720      Bootstrap網頁實作PHP Apache商業網站
# 4   20200720                全方位網路系統工程師就業認證養成班
# 5   20200720                   JavaScript程式設計
# 6   20200720               企業IT服務伺服器架設與選擇方案導覽
# 7   20200720           Power BI Desktop數據分析實戰
# 8   20200720                    AI電腦視覺OpenCV
# 9   20200720                資訊安全分析實務-方法、流程與工具
# 10  20200720        Systems Operations on AWS
# 11  20200720            CCNA認證-建置與管理Cisco解決方案
# 12  20200720            Apache Hadoop之管理者訓練課程
# 13  20200720           部署及管理Citrix SD-WAN基礎知識
# 14  20200720     EC-Council安全運營中心(SOC)分析師認證課程
# 15  20200720                PostgreSQL資料庫基礎管理
# 16  20200720                   SSCP資安專業人員認證課程
# 17  20200720           ITIL® 4 Foundation認證課程
# 18  20200720             IIB Council區塊鏈專家認證課程
# 19  20200720            Microsoft Azure開發解決方案
# 20  20200720                        Swift程式語言
# 21  20200720                        MySQL效能調校
# 22  20200720                  開發Java EE 7應用程式
# 23  20200720           Oracle Solaris 11 系統管理
# 24  20200720                       Python程式設計
# 25  20200720                  PMP®國際專案管理師培訓課程
# 26  20200720                Red Hat紅帽RHCE認證課程
# 27  20200720           Salesforce平台應用程序建構認證課程
# 28  20200720    Veritas NetBackup資料保護專業人員認證課程
# 29  20200720          VMware vSphere安裝及設定管理課程
# 30  20200720            CCNA認證-建置與管理Cisco解決方案
# 31  20200720            CCNA認證-建置與管理Cisco解決方案
# 32  20200720            Microsoft Azure開發解決方案
# 33  20200720        Systems Operations on AWS
# 34  20200720          VMware Horizon安裝及設定管理課程
# 35  20200720                    AI電腦視覺OpenCV
# 36  20200720                   JavaScript程式設計
# 37  20200720       Kotlin程式設計-Android應用程式開發實務
# 38  20200720                        MySQL效能調校
# 39  20200720           Power BI Desktop數據分析實戰
# 40  20200720     EC-Council安全運營中心(SOC)分析師認證課程
# 41  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程
# 42  20200720  ISO 27001：2013資訊安全管理系統主導稽核員訓練課程
# 43  20200720              Dreamweaver專業網頁編輯應用
#
#                                              audience  price hours  \
# 0    適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...  50000    40
# 1            適合對象  跨領域學習工作者 對網路安全技術有興趣者 初階系統/網路工程師     45000    40
# 2    適合對象  資訊機房(Data Center)管理、維護者 資訊機房(Data Cente...  60000    14
# 3    適合對象 有Dreamweaver與Bootstrap使用經驗，希望學會與PHP/MySQ...  12000    24
# 4    適合對象  電腦、資訊等相關科系畢業生，為獲取更多更深的企業資訊管理知識與取得專業國際認證...  89000   560
# 5    適合對象  想要撰寫或設計網頁的設計師 想要了解用戶端開發技術的程式設計師 想要撰寫網站應...  22000    28
# 6    適合對象  對IT產業有興趣、想從事伺服器管理相關工作者  想學習認識企業建構伺服器有哪些...   6000     7
# 7    適合對象  想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者 ...  20000    21
# 8                    適合對象 已有C++程式設計基礎、Python程式設計基礎者    24000    35
# 9    適合對象  想要學習資安實用操作技巧的IT人員 對系統的資安有興趣管理，希望能加強實作技巧...  28000    35
# 10   適合對象  系統管理人員 軟體開發人員(主要以AWS開發DevOps，搭配營運目的為主；非...  34020    21
# 11   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...  66000    70
# 12              適合對象 1.系統管理人員 2.IT經理 3.RDBMS資料庫管理人員    64000    28
# 13   適合對象 專為使用Citrix SD-WAN的IT專業人員所設計，幾乎沒有以前的SD-WA...  45000    24
# 14   適合對象  SOC分析師(第一級和第二級) 網路和安全管理員 網路和安全工程師 網路防禦分...  39000    24
# 15   適合對象  想要了解PostgreSQL基本管理功能的資料庫管理人員 想要了解Postgr...  38000    18
# 16   適合對象  對資訊安全工作有興趣者 欲取得SSCP®認證資格者 欲充實本身資安技術能力的I...  40000    40
# 17   適合對象 1.中高階營運相關主管 2.資訊長或企業資訊部門的主管 3.即將晉升管理工作之I...  34000    28
# 18   適合對象  商業技術主管 政府技術幕僚 全端工程師(Full Stack Develope...  56000    40
# 19             適合對象 想要建構雲端解決方法(如應用程式與服務等)的Azure開發人員    30000    35
# 20   適合對象  具備程式開發與物件導向設計經驗的程式設計師 想要熟悉Swift程式語言的程式設...  24000    28
# 21   適合對象  維護MySQL伺服器的資料庫管理人員 設計或使用MySQL資料庫的資料庫開發人...  57300    24
# 22   適合對象  希望開發遵循Java EE標準之完整企業應用程式及EJB元件的Java技術程式...  71600    30
# 23                               適合對象  系統管理者 維護工程師     71600    30
# 24                        適合對象 想了解Python程式語言的程式開發人員    18000    28
# 25   適合對象  欲參與考試，取得PMP®證照者 欲找到有效且系統化方法來執行專案之專案經理 欲...  32000    42
# 26   適合對象 1.Linux入門者、具備網路基本架構概念者 2.想要學習一般Linux使用操作...  68000    91
# 27                 適合對象  系統管理員 系統整合人員 獨立軟體供應商(ISV)     66000    35
# 28   適合對象  在其環境中負責Veritas NetBackup安裝、運作或整合的系統或網路管...  75000    40
# 29                               適合對象  系統管理員 系統工程師     69900    35
# 30   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...  66000    70
# 31   適合對象 1.對通訊產業有高度興趣，欲從事相關工作者 2.從事網路維運相關工作者 3.想要...  66000    70
# 32             適合對象 想要建構雲端解決方法(如應用程式與服務等)的Azure開發人員    30000    35
# 33   適合對象  系統管理人員 軟體開發人員(主要以AWS開發DevOps，搭配營運目的為主；非...  34020    21
# 34          適合對象 終端客戶公司的IT部門技術人員，以及負責交付遠端或虛擬桌面服務的人員    69900    35
# 35                   適合對象 已有C++程式設計基礎、Python程式設計基礎者    24000    35
# 36   適合對象  想要撰寫或設計網頁的設計師 想要了解用戶端開發技術的程式設計師 想要撰寫網站應...  22000    28
# 37   適合對象 1.想學習Kotlin程式語言的應用程式開發人員 2.已經熟悉Java程式設計語...  24000    35
# 38   適合對象  維護MySQL伺服器的資料庫管理人員 設計或使用MySQL資料庫的資料庫開發人...  57300    24
# 39   適合對象  想要深入了解及學習Power BI Desktop技術，以豐富資料分析報表者 ...  20000    21
# 40   適合對象  SOC分析師(第一級和第二級) 網路和安全管理員 網路和安全工程師 網路防禦分...  39000    24
# 41   適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...  50000    40
# 42   適合對象 1.資訊技術 (IT) 與信息安全 (IS) 相關經理人 2.風險管理相關經理人...  50000    40
# 43                             適合對象 欲學習專業網站建置與編輯應用者     8400    24
#
#                                               purpose  \
# 0   此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 1   資訊與通信科技（Information and Communication Technolo...
# 2   現階段大多數企業都建置IT系統，依靠IT提供關鍵服務，因此資訊機房(Data Center)...
# 3   Dreamweaver CC 2015之後的版本，已將Bootstrap整合為內建功能，因此...
# 4   根據 104 人力銀行「2020 薪酬趨白皮書調查」指出，產業加薪幅度三強分別為： 軟體及網...
# 5   由於網站應用程式的盛行，已經讓JavaScript變成世界最受歡迎的程式語言之一，也是最廣泛...
# 6   IT的e化環境，與企業架設伺服器息息相關，這也是企業系統管理員主要的工作內容之一。所以就了解...
# 7   數據分析已成為目前企業決勝的關鍵，唯有對手上的資料數據了解的越多，我們也才能做的更多及更好。...
# 8   OpenCV是一個行之有年的影像處理函式庫，除了用在傳統的影像應用程式之外，更被用於各式的深...
# 9   建立一套標準化的流程，將資訊安全的理論應用於各種日常維運的系統環境中，並順利通過資安弱點掃描...
# 10  當雲端部署蔚為時尚時，有效率的管理相形之下就顯得非常重要。在AWS平台上能以自動化的方式部署...
# 11  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 12  本課程將教您關於管理、操作、維護Hadoop叢集所需必要步驟的廣泛介紹。從安裝、組態到負載平...
# 13  學習各種可用的SD-WAN實作和部署模式，以及如何選擇適合您組織的模式。瀏覽SD-WAN的深...
# 14  隨著資訊安全領域的不斷擴展，SOC團隊需要提供高質量的IT安全服務，以主動檢測潛在的網路威脅...
# 15  本課程為PostgreSQL資料庫管理的入門課程，可以學習到管理PostgreSQL資料庫所...
# 16  *此課程為「行政院國家資通安全會報」認可之資通安全專業證照 對於有志從事資訊安全工作者，該如...
# 17  本課程將輔導您具備通過ITIL® 4 Foundation認證考試的能力，協助您了解ITIL...
# 18  網路傳遞資訊，區塊鏈傳遞價值。區塊鏈是去中心化(decentralization)策略的基石...
# 19  這門課程主要是讓您了解如何開發Azure的基礎架構，牽涉到開發過程的全部階段，包括從解決方法...
# 20  iPhone與iPad是目前Apple最火紅的行動上網裝置，為了簡化Objective-C與...
# 21  您需要管理MySQL應用中不斷增加的資料嗎？您想監控與診斷MySQL的疑難雜症並調校其最佳效...
# 22  本課程將教導建立Java EE 7應用程式的相關知識。課程內容涵蓋必要的Java EE元件，...
# 23  本課程介紹 Oracle Solaris 11 作業環境的基本管理，從安裝、升級、軟體套件、...
# 24  Python是一種物件導向、直譯式的電腦程式語言。它的語法簡單，能夠輕鬆完成很多常見的任務，...
# 25  培訓專案經理及企業主管人才，使其具備「專案自起始、規劃、執行、監控至結束」所需的管理知識與標...
# 26  雲端！絶對是當下最為熱門的話題之一，也是未來網路服務的主軸，這方向肯定是不會改變的，因Red...
# 27  通過此次培訓，您將具備一定的專業性，掌握Salesforce的一整套點擊式設定，不需編寫程式...
# 28  本課程提供Veritas NetBackup 8.1版軟體功能的教學。課程設計旨在提供您使用...
# 29  This five-day course features intensive hands-...
# 30  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 31  Cisco為全球網路設備領導廠商，本課程將帶領您探索Cisco網路世界的重要入門課程，本課程...
# 32  這門課程主要是讓您了解如何開發Azure的基礎架構，牽涉到開發過程的全部階段，包括從解決方法...
# 33  當雲端部署蔚為時尚時，有效率的管理相形之下就顯得非常重要。在AWS平台上能以自動化的方式部署...
# 34  This five-day, hands-on course gives you the s...
# 35  OpenCV是一個行之有年的影像處理函式庫，除了用在傳統的影像應用程式之外，更被用於各式的深...
# 36  由於網站應用程式的盛行，已經讓JavaScript變成世界最受歡迎的程式語言之一，也是最廣泛...
# 37  針對想要使用Kotlin開發Android應用程式設計的課程，適合初學或具備Java、And...
# 38  您需要管理MySQL應用中不斷增加的資料嗎？您想監控與診斷MySQL的疑難雜症並調校其最佳效...
# 39  數據分析已成為目前企業決勝的關鍵，唯有對手上的資料數據了解的越多，我們也才能做的更多及更好。...
# 40  隨著資訊安全領域的不斷擴展，SOC團隊需要提供高質量的IT安全服務，以主動檢測潛在的網路威脅...
# 41  此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 42  此課程為「行政院國家資通安全會報」認可之資通安全專業證照 資訊(Information)可說...
# 43  本課程將學習如何從網頁的基礎內容編輯開始，進行HTML檔案格式的編排與設計，了解網頁格式的特...
#
#                                               content  \
# 0   1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...
# 1    Explain the OSI and TCP/IP Models (解釋OSI和TCP/...
# 2   Importance and Causes for Downtime Standards a...
# 3   1.Bootstrap頁面準備與相關擴充元件應用 1-1.建構Bootstrap頁面 1-2...
# 4   網路基礎  網路基礎架構與網路服務  Windows系統管理建置  Windows Serv...
# 5    JavaScript簡介 JavaScript變數宣告方式、變數範圍、程式語法與基本型別 ...
# 6    企業常見IT伺服器平台介紹 企業常見IT伺服器應用介紹 File伺服器介紹 Proxy/N...
# 7    Power BI產品組合介紹 Power BI Desktop的下載與安裝 Power B...
# 8   1.編譯安裝OpenCV 2.Python與OpenCV的連結 3.圖片處理與標記 4.影像...
# 9    評估系統的資訊安全 評估流程與相關工具 列舉與入侵系統的參考步驟 駭客的矛盾對決 探索與測...
# 10   System Operations on AWS概論 在雲端的網路與運算 在雲端的資料倉儲...
# 11  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...
# 12  1.Introduction 2.Cloudera Enterprise Data Hub ...
# 13   Citrix SD-WAN簡介和概述 •      CitrixSD-WAN功能 •   ...
# 14   安全運營和管理(Security Operations and Management) 了...
# 15   PostgreSQL系統架構(PostgreSQL System Architecture...
# 16  第一章 Introducing Security and Aligning Asset Ma...
# 17  1.ITIL®4基礎 1-1 ITIL®4 概述(Overview of ITIL®4) 1...
# 18   掌握區塊鏈技術的理論和技術基礎 了解去中心化(decentralization)的概念，其...
# 19   建立、設定、監控以及延展Azure App Service Web Apps 實作Azur...
# 20   Xcode開發工具介紹 Swift簡介 Swift基本語法結構 Swift運算子與流程控制...
# 21   課程介紹 效能調校概念說明 效能調校工具介紹 Performance Schema說明 伺...
# 22   Java EE概論、Java EE模組與元件開發步驟 使用Netbeans開發工具 使用J...
# 23   安裝Oracle Solaris 11 使用IPS 升級 Oracle Solaris 1...
# 24   Python語言及開發環境介紹 資料型別 集合 結構控制 函數 模組(Module) 物件...
# 25  PMBOK® Guide-Sixth Edition+Agile Practice Guid...
# 26   RH124： Red Hat紅帽系統管理 I (35小時) RH134： Red Hat紅...
# 27   構建資料模型 1-1    核心CRM物件的功能 1-2    聲明式客製的界限 1-3 ...
# 28   介紹Veritas NetBackup 設定NetBackup儲存單元 建立備立政策及排程...
# 29   Course Introduction Introduction to vSphere a...
# 30  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...
# 31  1.建立網路與區域網路的基礎概念 2.深入瞭解TCP/IP通訊協定（包含新一代IPv6通訊協...
# 32   建立、設定、監控以及延展Azure App Service Web Apps 實作Azur...
# 33   System Operations on AWS概論 在雲端的網路與運算 在雲端的資料倉儲...
# 34   Course Introduction Introduction to VMware Ho...
# 35  1.編譯安裝OpenCV 2.Python與OpenCV的連結 3.圖片處理與標記 4.影像...
# 36   JavaScript簡介 JavaScript變數宣告方式、變數範圍、程式語法與基本型別 ...
# 37    Kotlin程式設計語言基礎 設計函式 類別與物件 物件導向程式設計 列舉型態、常數與資...
# 38   課程介紹 效能調校概念說明 效能調校工具介紹 Performance Schema說明 伺...
# 39   Power BI產品組合介紹 Power BI Desktop的下載與安裝 Power B...
# 40   安全運營和管理(Security Operations and Management) 了...
# 41  1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...
# 42  1.資訊安全管理系統要求 (ISO/IEC 27001) 2.資訊安全管理系統要求 (ISO...
# 43  1.網站定義與基本操作  1-1網頁檔案基本規則 1-2 定義網站 1-3 檔案基本操作 1...
#
#                                                during
# 0   ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 1   ['2020/07/27 ~ 2020/07/31 每週一二三四五', '2020/08/1...
# 2   ['2020/07/27 ~ 2020/07/28 每週一二', '2020/08/20 ~...
# 3   ['2020/09/14 ~ 2020/10/07 每週一三', '2020/10/26 ~...
# 4   ['2020/07/31 ~ 2021/01/19 每週一二四五', '2020/11/09...
# 5   ['2020/08/15 ~ 2020/08/23 每週六日', '2020/10/19 ~...
# 6                     ['2020/10/30 ~ 2020/10/30 每週五']
# 7   ['2020/08/03 ~ 2020/08/05 每週一二三', '2020/10/31 ...
# 8                 ['2020/11/23 ~ 2020/11/27 每週一二三四五']
# 9   ['2020/07/25 ~ 2020/08/09 每週六日', '2020/10/12 ~...
# 10  ['2020/09/28 ~ 2020/09/30 每週一二三', '2020/11/30 ...
# 11  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 12                 ['2020/09/22 ~ 2020/09/25 每週二三四五']
# 13                                                 []
# 14  ['2020/08/12 ~ 2020/08/14 每週三四五', '2020/10/05 ...
# 15                  ['2020/09/28 ~ 2020/09/30 每週一二三']
# 16  ['2020/08/31 ~ 2020/09/04 每週一二三四五', '2020/10/2...
# 17  ['2020/08/17 ~ 2020/08/20 每週一二三四', '2020/09/05...
# 18  ['2020/08/24 ~ 2020/08/28 每週一二三四五', '2020/11/3...
# 19                ['2020/09/21 ~ 2020/09/25 每週一二三四五']
# 20                 ['2020/11/24 ~ 2020/11/27 每週二三四五']
# 21                  ['2020/08/24 ~ 2020/08/26 每週一二三']
# 22                ['2020/11/09 ~ 2020/11/13 每週一二三四五']
# 23                ['2020/10/19 ~ 2020/10/23 每週一二三四五']
# 24  ['2020/08/10 ~ 2020/08/13 每週一二三四', '2020/09/05...
# 25  ['2020/08/05 ~ 2020/08/14 每週三四五', '2020/08/15 ...
# 26  ['2020/08/20 ~ 2020/11/19 每週二四', '2020/09/12 ~...
# 27                ['2020/10/26 ~ 2020/10/30 每週一二三四五']
# 28                ['2020/09/14 ~ 2020/09/18 每週一二三四五']
# 29  ['2020/08/03 ~ 2020/08/07 每週一二三四五', '2020/08/2...
# 30  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 31  ['2020/07/30 ~ 2020/10/08 每週二四', '2020/08/15 ~...
# 32                ['2020/09/21 ~ 2020/09/25 每週一二三四五']
# 33  ['2020/09/28 ~ 2020/09/30 每週一二三', '2020/11/30 ...
# 34                ['2020/09/14 ~ 2020/09/18 每週一二三四五']
# 35                ['2020/11/23 ~ 2020/11/27 每週一二三四五']
# 36  ['2020/08/15 ~ 2020/08/23 每週六日', '2020/10/19 ~...
# 37  ['2020/08/31 ~ 2020/09/04 每週一二三四五', '2020/09/0...
# 38                  ['2020/08/24 ~ 2020/08/26 每週一二三']
# 39  ['2020/08/03 ~ 2020/08/05 每週一二三', '2020/10/31 ...
# 40  ['2020/08/12 ~ 2020/08/14 每週三四五', '2020/10/05 ...
# 41  ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 42  ['2020/08/10 ~ 2020/08/14 每週一二三四五', '2020/08/1...
# 43  ['2020/09/07 ~ 2020/09/10 每週一二三四五', '2020/10/1...
# 新增成功
# 結束寫入

# %%
weekday_list=[]
weekends_list=[]
for n in range(len(df['during'])): 
    try:
        if "六" in df['during'][n].split(",")[0] or "日" in df['during'][n].split(",")[0]:
            weekends_list.append(True)
            if "一" in df['during'][n].split(",")[0] or "二" in df['during'][n].split(",")[0] or "三" in df['during'][n].split(",")[0] or "四" in df['during'][n].split(",")[0] or "五" in df['during'][n].split(",")[0]:
                weekday_list.append(True)
            else:
                weekday_list.append(False)
        elif "一" in df['during'][n].split(",")[0] or "二" in df['during'][n].split(",")[0] or "三" in df['during'][n].split(",")[0] or "四" in df['during'][n].split(",")[0] or "五" in df['during'][n].split(",")[0]:
            weekends_list.append(False)
            weekday_list.append(True)
        else:
            weekday_list.append(np.nan)
            weekends_list.append(np.nan)
    except Exception as e:
        print(str(e))

# %%
print(weekday_list,weekends_list)
# Out:
# [True, True, True, True, True, False, True, True, True, False, True, True, True, nan, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True] [False, False, False, False, False, True, False, False, False, True, False, False, False, nan, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False]

# %%
df['during'][0].split(",")[0]
# Out:
# "['2020/08/10 ~ 2020/08/14 每週一二三四五'"

# %%
from monitor import monitor
import sys
import traceback
import os
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.chrome.options import Options
import requests
from tqdm import tqdm
import pandas as pd
from datetime import datetime 
from sqlalchemy import create_engine
import numpy as np
chrome_options=Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--headless')
#隱藏彈出視窗
chrome_driver_path="/Users/chih-liangyang/Downloads/chromedriver"
#指定chromedriver在本機的位置
driver = webdriver.Chrome(chrome_driver_path, chrome_options=chrome_options)
url="https://www.uuu.com.tw/Course"
try: 
#        driver.implicitly_wait(20)
    driver.get(url)
    driver.implicitly_wait(20)#給予等待時間渲染網頁
    html = driver.page_source
    soup=bs(html,"lxml")
    raw_data=soup.find_all("div","panel-body")#抓所有的區塊
    urls=[]
    for i in raw_data:
        a=1
        try:
            urls.append("https://www.uuu.com.tw"+i.find('a').get('href'))#找個別的網址放入list
        except:
            print("第"+a+"個有缺網址")
            continue
        a+=1
    time_list=[]
    try:
        for j in tqdm(range(len(urls))):
            driver.get(urls[j])
            driver.implicitly_wait(10)
            try:
                time=driver.find_elements_by_xpath("/html/body/article/section[2]/div[1]/div[2]/div[1]/table/tbody/tr[2]/td[4]")
                time_list.append(time[0].text)
            except:
                time_list.append(np.nan)
    except Exception as e:
        print(str(e))
        
except Exception as e:    
    print(str(e)) #報錯誤 
finally:
    print(time_list)
    driver.quit()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: DeprecationWarning: use options instead of chrome_options
#
#   0%|          | 0/44 [00:00<?, ?it/s]
#   2%|▏         | 1/44 [00:00<00:18,  2.33it/s]
#   5%|▍         | 2/44 [00:01<00:31,  1.33it/s]
#   7%|▋         | 3/44 [00:02<00:34,  1.19it/s]
#   9%|▉         | 4/44 [00:03<00:27,  1.47it/s]
#  11%|█▏        | 5/44 [00:04<00:27,  1.41it/s]
#  14%|█▎        | 6/44 [00:04<00:22,  1.72it/s]
#  16%|█▌        | 7/44 [00:04<00:17,  2.07it/s]
#  18%|█▊        | 8/44 [00:05<00:17,  2.10it/s]
#  20%|██        | 9/44 [00:05<00:14,  2.48it/s]
#  23%|██▎       | 10/44 [00:05<00:11,  2.84it/s]
#  25%|██▌       | 11/44 [00:05<00:10,  3.08it/s]
#  27%|██▋       | 12/44 [00:06<00:11,  2.80it/s]
#  30%|██▉       | 13/44 [00:06<00:11,  2.77it/s]
#  32%|███▏      | 14/44 [00:26<03:10,  6.34s/it]
#  34%|███▍      | 15/44 [00:27<02:11,  4.52s/it]
#  36%|███▋      | 16/44 [00:27<01:30,  3.23s/it]
#  39%|███▊      | 17/44 [00:27<01:03,  2.36s/it]
#  41%|████      | 18/44 [00:27<00:44,  1.73s/it]
#  43%|████▎     | 19/44 [00:28<00:32,  1.29s/it]
#  45%|████▌     | 20/44 [00:28<00:23,  1.01it/s]
#  48%|████▊     | 21/44 [00:28<00:17,  1.28it/s]
#  50%|█████     | 22/44 [00:29<00:14,  1.57it/s]
#  52%|█████▏    | 23/44 [00:29<00:10,  1.93it/s]
#  55%|█████▍    | 24/44 [00:29<00:09,  2.20it/s]
#  57%|█████▋    | 25/44 [00:29<00:07,  2.41it/s]
#  59%|█████▉    | 26/44 [00:30<00:09,  1.97it/s]
#  61%|██████▏   | 27/44 [00:31<00:09,  1.81it/s]
#  64%|██████▎   | 28/44 [00:31<00:07,  2.16it/s]
#  66%|██████▌   | 29/44 [00:31<00:06,  2.45it/s]
#  68%|██████▊   | 30/44 [00:32<00:05,  2.71it/s]
#  70%|███████   | 31/44 [00:32<00:04,  2.62it/s]
#  73%|███████▎  | 32/44 [00:32<00:04,  2.56it/s]
#  75%|███████▌  | 33/44 [00:33<00:03,  2.88it/s]
#  77%|███████▋  | 34/44 [00:33<00:03,  3.15it/s]
#  80%|███████▉  | 35/44 [00:33<00:02,  3.25it/s]
#  82%|████████▏ | 36/44 [00:34<00:02,  3.49it/s]
#  84%|████████▍ | 37/44 [00:34<00:01,  3.58it/s]
#  86%|████████▋ | 38/44 [00:34<00:01,  3.04it/s]
#  89%|████████▊ | 39/44 [00:35<00:01,  3.03it/s]
#  91%|█████████ | 40/44 [00:35<00:01,  2.81it/s]
#  93%|█████████▎| 41/44 [00:35<00:00,  3.09it/s]
#  95%|█████████▌| 42/44 [00:35<00:00,  3.28it/s]
#  98%|█████████▊| 43/44 [00:36<00:00,  3.40it/s]
# 100%|██████████| 44/44 [00:36<00:00,  1.20it/s]

# %%
time_list
# Out:
# ['09:00~18:00',
#  '09:00~18:00',
#  '09:00~17:00',
#  '18:30~21:30',
#  '09:00~16:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '18:30~22:00',
#  '09:00~17:00',
#  nan,
#  '09:00~18:00',
#  '09:30~16:30',
#  '09:00~18:00',
#  '09:00~17:00',
#  '09:00~18:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~18:00',
#  '09:00~16:30',
#  '09:00~16:30',
#  '09:00~17:00',
#  '09:00~17:00',
#  '18:30~22:00',
#  '09:00~17:00',
#  '09:30~17:30',
#  '09:00~17:00',
#  '18:30~22:00',
#  '18:30~22:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~17:00',
#  '09:00~18:00',
#  '09:00~17:00',
#  '09:00~18:00',
#  '09:00~18:00',
#  '09:00~18:00',
#  '09:00~16:00']

# %%
start_time_list=[]
end_time_list=[]
for j in time_list:
#    print(j)
    try:
        a= j.replace('~', '')
        start_time=a[:5]
        start_time_list.append(start_time)
        end_time=a[5:]
        end_time_list.append(end_time)
    except:
        a=j
        start_time_list.append(np.nan)
        end_time_list.append(np.nan)        
print(start_time_list,end_time_list)
# Out:
# ['09:00', '09:00', '09:00', '18:30', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '18:30', '09:00', nan, '09:00', '09:30', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '18:30', '09:00', '09:30', '09:00', '18:30', '18:30', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00', '09:00'] ['18:00', '18:00', '17:00', '21:30', '16:00', '17:00', '17:00', '17:00', '17:00', '17:00', '17:00', '22:00', '17:00', nan, '18:00', '16:30', '18:00', '17:00', '18:00', '17:00', '17:00', '18:00', '16:30', '16:30', '17:00', '17:00', '22:00', '17:00', '17:30', '17:00', '22:00', '22:00', '17:00', '17:00', '17:00', '17:00', '17:00', '17:00', '18:00', '17:00', '18:00', '18:00', '18:00', '16:00']

# %%
def get_time():
    chrome_options=Options()
    chrome_options.add_argument('--no-sandbox')
    chrome_options.add_argument('--disable-dev-shm-usage')
    chrome_options.add_argument('--headless')
    #隱藏彈出視窗
    chrome_driver_path="/Users/chih-liangyang/Downloads/chromedriver"
#    chrome_driver_path="/root/chromedriver"
    #指定chromedriver在本機的位置
    driver = webdriver.Chrome(chrome_driver_path, chrome_options=chrome_options)
    url="https://www.uuu.com.tw/Course"
    try: 
        driver.get(url)
        driver.implicitly_wait(20)#給予等待時間渲染網頁
        html = driver.page_source
        soup=bs(html,"lxml")
        raw_data=soup.find_all("div","panel-body")#抓所有的區塊
        urls=[]
        for i in raw_data:
            a=1
            try:
                urls.append("https://www.uuu.com.tw"+i.find('a').get('href'))#找個別的網址放入list
            except:
                 now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
                with opn(detailerr,'a') as file:            
                    file.write(now+"抓取所有網址時: 第"+ a + "個有缺網址")
                    file.write('\n')
                #print("第"+a+"個有缺網址")
                continue
            a+=1
        time_list=[]
        try:
            for j in tqdm(range(len(urls))):
                driver.get(urls[j])
                driver.implicitly_wait(10)
                try:
                    time=driver.find_elements_by_xpath("/html/body/article/section[2]/div[1]/div[2]/div[1]/table/tbody/tr[2]/td[4]")
                    time_list.append(time[0].text)
                except:
                    time_list.append(np.nan)
        except Exception as e:
            now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
            with opn(detailerr,'a') as file:            
                    file.write(now+"執行抓取時間有錯誤: "+ str(e))
                    file.write('\n')
                    #print(str(e))
    except Exception as e:
        now = datetime.now().strftime("[%Y%m%d %H:%M:%S]")
        with opn(detailerr,'a') as file:            
                file.write(now+"執行整個抓取程式有錯誤: "+ str(e))
                file.write('\n')
        #print(str(e)) #報錯誤 
    finally:
        return time_list
        #print(time_list)
        driver.quit()
